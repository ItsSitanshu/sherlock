# %% [markdown]
# # Analysis of the synthetic data

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
df_gwh = pd.read_csv("data/gateway_wallethistory.csv")
# df_qr = pd.read_csv("data/qrapp_fonepaytransaction.csv")
# df_svc = pd.read_csv("data/service_servicelog.csv")
# df_rem = pd.read_csv("data/remittance_remittance.csv")
# df_dis = pd.read_csv("data/disbursement_transaction.csv")

df_gwh.head()
